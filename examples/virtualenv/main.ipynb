# %% [markdown]
# # Example 2
#
# Created using python virtualenv.

# %%
# install some dependencies
# !pip install pandas numpy matplotlib sklearn
# Out:
# Collecting pandas
#   Using cached pandas-0.25.3-cp37-cp37m-macosx_10_9_x86_64.whl (10.2 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.1.2-cp37-cp37m-macosx_10_9_x86_64.whl (13.2 MB)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting pytz>=2017.2
#   Downloading pytz-2019.3-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 1.9 MB/s eta 0:00:01
# Collecting numpy>=1.13.3
#   Using cached numpy-1.18.1-cp37-cp37m-macosx_10_9_x86_64.whl (15.1 MB)
# Requirement already satisfied: python-dateutil>=2.6.1 in ./env/lib/python3.7/site-packages (from pandas) (2.8.1)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Using cached pyparsing-2.4.6-py2.py3-none-any.whl (67 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.1.0-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (113 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-0.22.1-cp37-cp37m-macosx_10_6_intel.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 6.0 MB/s eta 0:00:01    |██████▋                         | 2.3 MB 3.8 MB/s eta 0:00:03     |███████████▍                    | 3.9 MB 3.8 MB/s eta 0:00:02     |████████████████████████▌       | 8.4 MB 6.0 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Requirement already satisfied: setuptools in ./env/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (45.1.0)
# Collecting joblib>=0.11
#   Downloading joblib-0.14.1-py2.py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 6.1 MB/s eta 0:00:01
# Collecting scipy>=0.17.0
#   Downloading scipy-1.4.1-cp37-cp37m-macosx_10_6_intel.whl (28.4 MB)
#      |████████████████████████████████| 28.4 MB 4.9 MB/s eta 0:00:01
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=9d8842391619c023a6182211febd6f040cac5e8f7ae081b3b25bbb6767861edc
#   Stored in directory: /Users/laurence/Library/Caches/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# Installing collected packages: pytz, numpy, pandas, pyparsing, kiwisolver, cycler, matplotlib, joblib, scipy, scikit-learn, sklearn
# Successfully installed cycler-0.10.0 joblib-0.14.1 kiwisolver-1.1.0 matplotlib-3.1.2 numpy-1.18.1 pandas-0.25.3 pyparsing-2.4.6 pytz-2019.3 scikit-learn-0.22.1 scipy-1.4.1 sklearn-0.0

# %% [markdown]
# ## Take an example from the internet:
# **Spectral clustering for image segmentation**
# https://scikit-learn.org/stable/auto_examples/cluster/plot_segmentation_toy.html

# %%
print(__doc__)

# Authors:  Emmanuelle Gouillart <emmanuelle.gouillart@normalesup.org>
#           Gael Varoquaux <gael.varoquaux@normalesup.org>
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt

from sklearn.feature_extraction import image
from sklearn.cluster import spectral_clustering

import treebeard

l = 100
x, y = np.indices((l, l))

center1 = (28, 24)
center2 = (40, 50)
center3 = (67, 58)
center4 = (24, 70)

radius1, radius2, radius3, radius4 = 16, 14, 15, 14

circle1 = (x - center1[0]) ** 2 + (y - center1[1]) ** 2 < radius1 ** 2
circle2 = (x - center2[0]) ** 2 + (y - center2[1]) ** 2 < radius2 ** 2
circle3 = (x - center3[0]) ** 2 + (y - center3[1]) ** 2 < radius3 ** 2
circle4 = (x - center4[0]) ** 2 + (y - center4[1]) ** 2 < radius4 ** 2

# #############################################################################
# 4 circles
img = circle1 + circle2 + circle3 + circle4

# We use a mask that limits to the foreground: the problem that we are
# interested in here is not separating the objects from the background,
# but separating them one from the other.
mask = img.astype(bool)

img = img.astype(float)
img += 1 + 0.2 * np.random.randn(*img.shape)

# Convert the image into a graph with the value of the gradient on the
# edges.
graph = image.img_to_graph(img, mask=mask)

# Take a decreasing function of the gradient: we take it weakly
# dependent from the gradient the segmentation is close to a voronoi
graph.data = np.exp(-graph.data / graph.data.std())

# Force the solver to be arpack, since amg is numerically
# unstable on this example
labels = spectral_clustering(graph, n_clusters=4, eigen_solver='arpack')
label_im = np.full(mask.shape, -1.)
label_im[mask] = labels

plt.matshow(img)
plt.matshow(label_im)

# #############################################################################
# 2 circles
img = circle1 + circle2
mask = img.astype(bool)
img = img.astype(float)

img += 1 + 0.2 * np.random.randn(*img.shape)

graph = image.img_to_graph(img, mask=mask)
graph.data = np.exp(-graph.data / graph.data.std())

labels = spectral_clustering(graph, n_clusters=2, eigen_solver='arpack')
label_im = np.full(mask.shape, -1.)
label_im[mask] = labels

plt.matshow(img)
plt.matshow(label_im)

plt.savefig('output/graph.png')
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# # Save dependencies

# %%
# !pip freeze > requirements.txt
