# %%
from dotenv import load_dotenv
import os

load_dotenv(verbose=True)

api_key = os.getenv('API_KEY')
print(f"API Key is {api_key}")
assert api_key == 'blah'
# test
# Out:
# API Key is blah

# %%
# !echo output > my_output/output.txt

# %%
# !echo output_2 > another_output/output_2.txt
